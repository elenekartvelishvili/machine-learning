# %%
import pandas as pd
from sklearn.ensemble import VotingClassifier,StackingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
iris=pd.read_excel("/content/Iris.xlsx")

myLabel=LabelEncoder()

iris['Species']=myLabel.fit_transform(iris['Species'])

y=iris['Species'].values
x=iris.drop('Species',axis=1).values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
voting =VotingClassifier(estimators =[('algo1',KNeighborsClassifier()),
                ('algo2',GaussianNB()),('algo3',SVC(probability=True))],voting='soft')

voting.fit(x_train,y_train)
print(voting.score(x_test,y_test))  #voting
# Out:
# 0.9666666666666667

# %%
stack =StackingClassifier(estimators =[('algo1',KNeighborsClassifier()),
                ('algo2',GaussianNB()),('algo3',SVC(probability=True))],final_estimator=LogisticRegression())

stack.fit(x_train,y_train)
print(stack.score(x_test,y_test))    #stacking
# Out:
# 0.9666666666666667
